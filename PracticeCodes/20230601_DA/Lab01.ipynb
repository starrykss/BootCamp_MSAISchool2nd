# %% [markdown]
# # Lab 01. ARMA 모델링 실습 (AR + MA)
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA    # ARIMA 모델에서 미분 계수(I)를 사용하지 않는 형태로 ARMA 모델을 사용한다.

# %% [markdown]
# - 시계열 데이터를 생성한다.

# %%
# 시계열 데이터 생성
np.random.seed(0)
n = 100    # 데이터 포인트 수
ar_params = [0.7]    # 자기 회귀 계수
ma_params = [0.4, -0.2]    # 이동 평균 계수
residuals = np.random.normal(0, 1, n)    # 잔차 생성

# %% [markdown]
# - ARMA(1, 2) 모델을 생성한다.

# %%
# ARMA(1, 2) 모델 생성
data = [0, 0]    # 초깃값 설정
for i in range(2, n):
    ar_term = ar_params[0] * data[i-1]
    ma_term = ma_params[0] * residuals[i-1] + ma_params[1] * residuals[i-2]
    data.append(ar_term + ma_term + residuals[i])

# %% [markdown]
# - 데이터 프레임을 생성한다.

# %%
# 데이터 프레임 생성
df = pd.DataFrame({'Value': data})

print(df)
# Out:
#        Value
# 0   0.000000
# 1   0.000000
# 2   0.785990
# 3   3.102550
# 4   4.739953
# ..       ...
# 95  2.160229
# 96  1.734016
# 97  2.862567
# 98  2.842957
# 99  2.085650
#
# [100 rows x 1 columns]

# %% [markdown]
# - ARMA(1, 2) 모델을 핏해보고 모델 정보를 출력해본다.

# %%
# ARMA(1, 2) 모델 적합
model = ARIMA(df['Value'], order=(1, 0, 2))
results = model.fit()

# %%
# ARMA(1, 2) 모델 정보 출력
print(results.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Value   No. Observations:                  100
# Model:                 ARIMA(1, 0, 2)   Log Likelihood                -140.937
# Date:                Tue, 20 Jun 2023   AIC                            291.874
# Time:                        22:07:00   BIC                            304.900
# Sample:                             0   HQIC                           297.146
#                                 - 100
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1564      0.510      0.307      0.759      -0.842       1.155
# ar.L1          0.7647      0.129      5.934      0.000       0.512       1.017
# ma.L1          0.3757      0.158      2.382      0.017       0.067       0.685
# ma.L2         -0.1727      0.175     -0.986      0.324      -0.516       0.171
# sigma2         0.9663      0.151      6.394      0.000       0.670       1.263
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                 0.19
# Prob(Q):                              0.92   Prob(JB):                         0.91
# Heteroskedasticity (H):               0.70   Skew:                             0.03
# Prob(H) (two-sided):                  0.31   Kurtosis:                         2.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# - 잔차 시계열 그래프를 출력해본다.

# %%
# 잔차 시계열 그래프 출력
plt.plot(results.resid)
plt.xlabel('Time')
plt.ylabel('Residuals')

plt.show()

# %% [markdown]
# - 예측 결과 그래프를 출력해본다.

# %%
# 예측 결과 그래프 출력
pred = results.predict(start=1, end=n)
plt.plot(df['Value'], label='Actual')
plt.plot(pred, label='ARMA')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()

plt.show()
