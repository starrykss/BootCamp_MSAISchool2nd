# %% [markdown]
# # Lab 02. 이미지 정제 : 정사각형 데이터 만들기
# ---

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
def expend2square(pil_img, backgound_color) : 
    width, height = pil_img.size
    print(width, height) 
    
    # 정사각형 
    if width == height :
        return pil_img
    
    # 너비가 높이 보다 큰 경우 처리하는 코드 
    elif width > height :
        result = Image.new(pil_img.mode, (width, width), backgound_color)
        result.paste(pil_img, (0, (width - height) // 2))

        """
        .paste() 메서드는 result 이미지 객체에 pil_img 이미지 객체를 (0, (width - height) // 2) 위치에 붙여넣는다. 
        따라서, pil_img 이미지는 result 이미지의 왼쪽 위 모서리에서부터 (0, (width - height) // 2) 좌표로 이동하여 붙여지게 된다.
        """

        return result
    else : 
        result = Image.new(pil_img.mode, (height, height), backgound_color)
        result.paste(pil_img, ((height - width) // 2, 0))
        return result
    
def resize_with_padding(pil_img, new_size, backgound_color) :
    img = expend2square(pil_img, backgound_color)
    img = img.resize((new_size[0], new_size[1]), Image.ANTIALIAS)
    
    return img

img = Image.open("./data/apple_1.png")

img_new = resize_with_padding(img, (400, 400), (0, 0, 0))
print(img_new.size)

plt.imshow(img_new)
plt.show()
# Out:
# 162 122
# (400, 400)
# c:\Users\kss34\anaconda3\envs\myEnv\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.

# %%
if "ignore" == label : 
    # 좌표 가져와서 
    # 사각형 그리기 통해서 검정으로 변환 시켜서 
    # 이미지 저장
# Out:
#   File "C:\Users\kss34\AppData\Local\Temp\ipykernel_43076\2082692364.py", line 4
#     # 이미지 저장
#              ^
# SyntaxError: unexpected EOF while parsing
