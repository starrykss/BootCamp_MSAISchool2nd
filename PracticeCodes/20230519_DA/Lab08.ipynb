# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 생성
data = np.random.randint(1, 7, size=100)
print(data)

unique, counts = np.unique(data, return_counts=True)
print(unique)

print(counts)
# Out:
# [4 3 2 5 3 2 3 5 2 3 5 4 4 5 1 1 5 1 5 4 5 4 2 3 1 2 5 6 4 2 3 5 2 3 5 4 1
#  4 5 5 3 5 4 1 6 6 2 4 6 2 1 3 1 1 2 3 1 1 4 4 6 5 5 1 2 6 2 6 6 5 3 5 4 1
#  4 2 3 4 5 3 4 1 3 5 3 1 1 5 4 2 3 5 6 6 2 3 4 2 2 5]
# [1 2 3 4 5 6]
# [16 17 17 18 22 10]

# %%
# 막대 그래프 시각화
fig, ax = plt.subplots()
ax.bar(unique, counts)
ax.set_xlabel('Value')
ax.set_ylabel('Frequency')
ax.set_title('Frequency Distribution')
plt.show()
